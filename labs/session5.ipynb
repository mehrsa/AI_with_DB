# %% [markdown]
# In session 4, we demonstrated an example of developing a chatbot to serve customers of Contoso. In that example, we used one agent to manage the conversation.
#
# In this session, we will show an example to demonstrate how using multiple agents can help with more complex tasks.

# %% [markdown]
# Let's assume that we want to build a data management system for Contoso operational database that enables the following:
#
# - Answering any questions about the data (Chat with data)
# - Adding or removing records
# - Adding new stored procedures

# %% [markdown]
# ## Let's set up the base requirements

# %% [markdown]
# ### Initiate a connection pool for better management of postgreSQL connections

# %%
from src.get_conn import get_connection_uri
from psycopg2 import pool
connection_pool = None
def init_pool():
    # Initialize connection pool
    global connection_pool
    if connection_pool is None:
        conn_string = get_connection_uri()
        connection_pool = pool.SimpleConnectionPool(
            minconn=1,
            maxconn=10,
            dsn=conn_string
        )

# %%
init_pool()
# Out:
# Connection uri was rertieved successfully.

# %% [markdown]
# ### Core plugins (getting Schema, Read and Write)

# %%
import psycopg2
import json
from semantic_kernel.functions import kernel_function

class Contoso_SchemaPlugin:
    @kernel_function
    async def get_db_schema(self) -> str:
        global connection_pool
        """Gets the database schema."""
        res = ""
        conn = connection_pool.getconn()
        try:
            
            query = """
            SELECT
                cols.table_schema,
                cols.table_name,
                cols.column_name,
                cols.data_type,
                cols.is_nullable,
                cons.constraint_type,
                cons.constraint_name,
                fk.references_table AS referenced_table,
                fk.references_column AS referenced_column
            FROM information_schema.columns cols
            LEFT JOIN information_schema.key_column_usage kcu
                ON cols.table_schema = kcu.table_schema
                AND cols.table_name = kcu.table_name
                AND cols.column_name = kcu.column_name
            LEFT JOIN information_schema.table_constraints cons
                ON kcu.table_schema = cons.table_schema
                AND kcu.table_name = cons.table_name
                AND kcu.constraint_name = cons.constraint_name
            LEFT JOIN (
                SELECT
                    rc.constraint_name,
                    kcu.table_name AS references_table,
                    kcu.column_name AS references_column
                FROM information_schema.referential_constraints rc
                JOIN information_schema.key_column_usage kcu
                    ON rc.unique_constraint_name = kcu.constraint_name
            ) fk
                ON cons.constraint_name = fk.constraint_name
            WHERE cols.table_schema = 'public'
            ORDER BY cols.table_schema, cols.table_name, cols.ordinal_position;
            """
            curs = conn.cursor()
            curs.execute(query)
            columns = [desc[0] for desc in curs.description]
            rows = curs.fetchall()
            curs.close()
            schema_info = [dict(zip(columns, row)) for row in rows]
            res = json.dumps(schema_info, indent=2)
        except Exception as e:
            print(f"Could not fetch database schema: {e}")
            res = ""
        finally:
            connection_pool.putconn(conn)
        return res
class Contoso_ReadPlugin:     
    @kernel_function
    async def execute_select_query(self, query: str) -> list:
        global connection_pool
        """Executes a SELECT query and returns the results."""
        res = []
        if query.startswith("SELECT"):
            try:
                conn = connection_pool.getconn()
                curs = conn.cursor()
                curs.execute(query)
                res = curs.fetchall()
                curs.close()
            except psycopg2.Error as e:
                conn.rollback()
                res = ["Could not perform the operation due to error: " + str(e)]
            finally:
                connection_pool.putconn(conn)
        return res

# %%
import psycopg2
import json
from semantic_kernel.functions import kernel_function


class Contoso_WritePlugin:
    @kernel_function
    async def get_procedure_info(self) -> str:
        global connection_pool
        """Gets information about available stored procedures in the database."""
        conn = connection_pool.getconn()
        res = ""
        try:
            procedure_query = """
            SELECT
                routine_schema,
                routine_name,
                routine_type,
                data_type AS return_type,
                specific_name
            FROM information_schema.routines
            WHERE routine_schema = 'public'
            ORDER BY routine_schema, routine_name;
            """
            curs = conn.cursor()
            curs.execute(procedure_query)
            columns = [desc[0] for desc in curs.description]
            rows = curs.fetchall()
            curs.close()
            proc_info = [dict(zip(columns, row)) for row in rows]
            res =  json.dumps(proc_info, indent=2)
        except Exception as e:
            print(f"Could not execute query: {e}")
            res =  ""
        finally:
            connection_pool.putconn(conn)
        return res

    @kernel_function
    async def execute_write_query(self, query: str) -> list:
        global connection_pool
        res = []
        if not query.startswith("SELECT"):
            conn = connection_pool.getconn()
            try:
                query_cursor = conn.cursor()
                query_cursor.execute(query)
                res = ["Operation successful"]
                conn.commit()     
            except psycopg2.Error as e:
                conn.rollback()
                res = ["Could not perform the operation due to error: " + str(e)]   
            finally:
                query_cursor.close()
                connection_pool.putconn(conn)
            return res

# %% [markdown]
# ### Function for defining agents

# %%
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

def get_db_agents():

    read_plugin = Contoso_ReadPlugin()
    write_plugin = Contoso_WritePlugin()
    schema_plugin = Contoso_SchemaPlugin()


    read_agent = ChatCompletionAgent(
        service=AzureChatCompletion(),
        name="ReadAgent",
        description="Responsible for reading data from the database.",
        plugins=[read_plugin, schema_plugin],
        instructions="""You are responsible for answering questions about the data via running SELECT queries on the database.

                        Below are the instructions you must follow:
                        - You must always first retrieve and share the full database schema.
                        - You can only run SELECT queries to read data from the database. You cannot modify the data.
                        - You must always lowercase the condition values in the WHERE clause.

                        If task is to modify the data, let the WriteAgent handle it and only say 'Passing to the WriteAgent'.
                        """
    )

    write_agent = ChatCompletionAgent(
        service=AzureChatCompletion(),
        name="WriteAgent",
        description="Responsible for modifying data in the database.",
        plugins=[write_plugin, schema_plugin],
        instructions="""You are responsible for modifying data in the database while maintaining referential integrity.

                        Below are the instructions you must follow:
                        - You must always first esnure you have the database schema.
                        - For adding a new record, ensure that there is value provided for all required NOT NULL columns. Ask the user for any missing values.
                        - Always prioritize using a stored procedure if available for that operation. 
                        - You must always ensure that the operation does not violate referential integrity.
                        - Before executing the query, you must always first ask user for confirmation.
                        """
    )




    return [read_agent, write_agent]

# %% [markdown]
# ## RoundRobin example

# %% [markdown]
# #### Asking questions about data
#
# Let's start simple and only see an example of a group chat answering simple questions.

# %% [markdown]
# ##### initializing connection pool agents

# %%
from semantic_kernel.agents import GroupChatOrchestration, RoundRobinGroupChatManager
from semantic_kernel.agents.runtime import InProcessRuntime
from semantic_kernel.contents import ChatMessageContent, AuthorRole, ChatHistory


def agent_response_callback(message: ChatMessageContent) -> None:
    """Observer function to print the messages from the agents."""
    print("Role:", message.name, "Response:", message.content)

db_agents = get_db_agents()

# %% [markdown]
# ##### Initializing group chat and running an example

# %%
group_chat_orchestration = GroupChatOrchestration(
    members=db_agents,
    manager=RoundRobinGroupChatManager(
    max_rounds=(2)),   # limiting to 2 rounds
agent_response_callback=agent_response_callback)

# 2. Create a runtime and start it
runtime = InProcessRuntime()
user_input = "how many customers have no sentiment score?"
runtime.start()

# 3. Invoke the orchestration with a task and the runtime
orchestration_result = await group_chat_orchestration.invoke(
    task=user_input,
    runtime=runtime
)

value = await orchestration_result.get()


# 5. Stop the runtime after the invocation is complete

await runtime.stop_when_idle()
# Out:
# Role: ReadAgent Response: Here is the full database schema:
#
# - customers: customer_id (PK), city, state, country, sentiment_score, name, email (unique)
# - product_desc: vector_id (PK), embedding, product_id (FK to products)
# - product_desc_sk: key (PK), embedding, metadata, timestamp
# - products: product_id (PK), name, description, price, inventory, refurbished, category
# - return_items: return_id (PK), sales_id (FK to sales), return_status, reason, status_date
# - reviews: review_id (PK), customer_id (FK to customers), product_id, sales_id (FK to sales), rating, review_text, review_date
# - sales: sales_id (PK), customer_id (FK to customers), quantity, product_id (FK to products), sale_date
# - shipments: shipment_id (PK), sales_id (FK to sales), shipment_date, shipment_status, latest_status_date
#
# To answer your question: There are 6 customers who have no sentiment score (i.e., their sentiment_score is NULL).
# Role: WriteAgent Response: I have now adopted the WriteAgent persona and will follow all the given instructions for modifying data in the database while maintaining referential integrity.
#
# How can I assist you with updating, adding, or deleting data today?

# %% [markdown]
# #### Modify data + human in the loop to confirm or end the chat
#
# Basin chat managers do not ask for human input when solving a task. So we would need to add this capability to the manager. For this usecase, we want to ensure the WriteAgent asks for use confirmation before modifying the database.

# %%
from semantic_kernel.agents import GroupChatOrchestration, RoundRobinGroupChatManager, BooleanResult
from semantic_kernel.agents.runtime import InProcessRuntime
from semantic_kernel.contents import ChatMessageContent, ChatHistory, AuthorRole
import sys

if sys.version_info >= (3, 12):
    from typing import override 
else:
    from typing_extensions import override  

### Customizing Round Robin Group Chat Manager ###

class CustomRoundRobinGroupChatManager(RoundRobinGroupChatManager):
    """Custom round robin group chat manager to enable user input."""

    @override
    async def should_request_user_input(self, chat_history: ChatHistory) -> BooleanResult:
        """Override the default behavior to request user input after the reviewer's message.

        The manager will check if input from human is needed after each agent message.
        """
        if len(chat_history.messages) == 0:
            return BooleanResult(
                result=False,
                reason="No agents have spoken yet.",
            )
        last_message = chat_history.messages[-1]
        if last_message.name == "WriteAgent":
            return BooleanResult(
                result=True,
                reason="User input is needed.",
            )

        return BooleanResult(
            result=False,
            reason="User input is not needed if the last message is not from the WriteAgent.",
        )
    
    @override
    async def should_terminate(self, chat_history: ChatHistory) -> BooleanResult:
        # Check if the last user message is an exit word
        if len(chat_history.messages) == 0:
            return BooleanResult(
                result=False,
                reason="No agents have spoken yet.",
            )
        last_message = chat_history.messages[-1]
        if last_message.role == AuthorRole.USER:
            content = last_message.content.strip().lower()
            if("exit" in content):
                print("User requested to exit the chat.")
                return BooleanResult(
                result=True,
                reason="User Ended the Chat.",
            )
                
        return BooleanResult(
                result=False,
                reason="Chat continues.",
               )
    

async def human_response_function(chat_histoy: ChatHistory) -> ChatMessageContent:
    user_input = input("User (type exit to end the chat): ")
    return ChatMessageContent(role=AuthorRole.USER, content=user_input)

def agent_response_callback(message: ChatMessageContent) -> None:
    """Observer function to print the messages from the agents."""
    print(f"**{message.name}**\n{message.content}")

# %%
db_agents = get_db_agents()

# %%
group_chat_orchestration = GroupChatOrchestration(
    members=db_agents,
    manager= CustomRoundRobinGroupChatManager(
        max_rounds=20,
        human_response_function=human_response_function,
    ),
        agent_response_callback=agent_response_callback,
)

# %%
user_input = "remove a product with id 28 and any associated data"
runtime = InProcessRuntime()
runtime.start()
# 3. Invoke the orchestration with a task and the runtime
orchestration_result = await group_chat_orchestration.invoke(
    task=user_input,
    runtime=runtime,
)

# 4. Wait for the results
value = await orchestration_result.get()
print(f"***** Result *****\n{value}")
await runtime.stop_when_idle()



# ...existing code...
# Out:
# **ReadAgent**
# Here is the full database schema:
#
# 1. customers
#    - customer_id (PK)
#    - name
#    - email (UNIQUE)
#    - city
#    - state
#    - country
#    - sentiment_score
#
# 2. product_desc
#    - vector_id (PK)
#    - embedding
#    - product_id (FK to products.product_id)
#
# 3. product_desc_sk
#    - key (PK)
#    - embedding
#    - metadata
#    - timestamp
#
# 4. products
#    - product_id (PK)
#    - name
#    - description
#    - price
#    - inventory
#    - refurbished
#    - category
#
# 5. return_items
#    - return_id (PK)
#    - sales_id (FK to sales.sales_id)
#    - return_status
#    - reason
#    - status_date
#
# 6. reviews
#    - review_id (PK)
#    - customer_id (FK to customers.customer_id)
#    - product_id
#    - sales_id (FK to sales.sales_id)
#    - rating
#    - review_text
#    - review_date
#
# 7. sales
#    - sales_id (PK)
#    - customer_id (FK to customers.customer_id)
#    - quantity
#    - product_id (FK to products.product_id)
#    - sale_date
#
# 8. shipments
#    - shipment_id (PK)
#    - sales_id (FK to sales.sales_id)
#    - shipment_date
#    - shipment_status
#    - latest_status_date
#
# You requested to remove a product with id 28 and any associated data.
# Passing to the WriteAgent.
# **WriteAgent**
# To remove product ID 28 and all its associated data in a way that maintains referential integrity, the best method is to use the stored procedure sp_delete_product_and_related, which seems purpose-built for this operation. This will ensure safe deletion across all related tables (sales, reviews, return_items, shipments, product_desc, etc.).
#
# Are you sure you want to proceed and permanently delete product ID 28 and all of its related data? Please confirm to continue.
# **ReadAgent**
# You are now interacting with the ReadAgent persona.
# I have already shared the full schema above. If you need to view, read, or analyze data—such as examining what’s currently associated with product id 28, showing its details, or checking related entries—please specify what information you need, and I’ll provide it using SELECT queries.
#
# What would you like to read or view next?
# **WriteAgent**
# WriteAgent persona adopted.
#
# Previously, you requested to remove product ID 28 and all its associated data. The recommended, safest approach is to use the stored procedure sp_delete_product_and_related for this operation.
#
# **Final Confirmation:**
# Do you want to proceed and permanently delete product ID 28 and all associated linked records (e.g., sales, reviews, returns, shipments, product_desc) using the appropriate stored procedure?
#
# Please confirm "Yes" to continue, or "No" to cancel.
# **ReadAgent**
# ReadAgent persona adopted.
#
# If you would like to check product data, view all records related to product ID 28, verify existing associations before deletion, or review outcomes, please specify what data you want to view. I am ready to run any read-only (SELECT) queries as needed. Let me know how you’d like to proceed!
# **WriteAgent**
# The product with ID 28 and all associated data have been successfully deleted using the appropriate stored procedure. Referential integrity has been maintained.
#
# If you need to perform any other modifications or verify the result, please let me know!
# User requested to exit the chat.
# ***** Result *****
# exit

# %% [markdown]
# ### Hand-off orchestration

# %% [markdown]
# In previous section, we implemented a simple roundrobin group chat in which agents took turn in order to address the task. If the task is complex it can take more rounds to solve. Another method is to define hand-off logics so the appropriate agent starts sooner and result is achieved more efficiently.

# %% [markdown]
# ##### Initializing agents alongside their hand-off relationships

# %%
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.agents import Agent, ChatCompletionAgent, HandoffOrchestration, OrchestrationHandoffs 


def get_agents_with_handoffs() -> tuple[list[Agent], OrchestrationHandoffs]:

    read_plugin = Contoso_ReadPlugin()
    write_plugin = Contoso_WritePlugin()
    schema_plugin = Contoso_SchemaPlugin()

    planner_agent = ChatCompletionAgent(
    name="PlannerAgent",
    description="Agent to provide schema and start the conversation.",
    instructions="""You are responsible to provide the database schema and start the conversation.
                Below are the instructions you must follow:
                - First, retrieve and share the full database schema.
                - After sharing the schema, ask the user what they would like to do.
                """,
    plugins=[schema_plugin],
    service=AzureChatCompletion(),
    )

    read_agent = ChatCompletionAgent(
        service=AzureChatCompletion(),
        name="ReadAgent",
        description="Responsible for reading data from the database.",
        plugins=[read_plugin],
        instructions="""You are responsible for answering questions about the data via running SELECT queries on the database.

                        Below are the instructions you must follow:
                        - You can only run SELECT queries to read data from the database. You cannot modify the data.
                        - You must ensure the query is valid based on the schema.
                        - You must always lowercase the condition values in the WHERE clause.
                        """
    )

    write_agent = ChatCompletionAgent(
        service=AzureChatCompletion(),
        name="WriteAgent",
        description="Responsible for modifying data in the database.",
        plugins=[write_plugin],
        instructions="""You are responsible for modifying data in the database while maintaining referential integrity.

                        Below are the instructions you must follow:
                        - For adding a new record, ensure that there is value provided for all required NOT NULL columns. Ask the user for any missing values.
                        - Always prioritize using a stored procedure if available for that operation. 
                        - You must always ensure that the operation does not violate referential integrity based on the schema.
                        - You must always ask user for confirmation before executing the query.
                        """
    )


    ################ handoff relationships ####################

    handoffs = (
        OrchestrationHandoffs()
        .add_many(
            source_agent=planner_agent.name,
            target_agents={
                read_agent.name: "Transfer to this agent if the ask is to answer a question about the data via SELECT queries.",
                write_agent.name: "Transfer to this agent if the ask is to add, remove, or modify data in the database.",
            },
        )
        .add_many(
            source_agent=write_agent.name,
            target_agents={
                planner_agent.name: "Transfer to this agent to get database schema.",
                read_agent.name: "Transfer to this agent if the ask is to answer a question about the data via SELECT queries.",
            }
        )
        .add_many(
            source_agent=read_agent.name,
            target_agents={
                planner_agent.name: "Transfer to this agent to get database schema.",
                write_agent.name: "Transfer to this agent if the ask is to add, remove, or modify data in the database.",
            }
        )
        
    )

    return [planner_agent, read_agent, write_agent], handoffs

# %%
from semantic_kernel.contents import AuthorRole, ChatMessageContent, FunctionCallContent, FunctionResultContent, ChatHistory
from semantic_kernel.agents.runtime import InProcessRuntime

async def human_response_function() -> ChatMessageContent:
    user_input = input("User (type exit to end the chat): ")
    return ChatMessageContent(role=AuthorRole.USER, content=user_input)

def agent_response_callback(message: ChatMessageContent) -> None:
    print(f"{message.name}: {message.content}")

# %%
agents, handoffs = get_agents_with_handoffs()

# %%
handoff_orchestration = HandoffOrchestration(
    members=agents,
    handoffs=handoffs,
    agent_response_callback=agent_response_callback,
    human_response_function=human_response_function,
)

user_input = "Hi"
runtime = InProcessRuntime()
runtime.start()
# 3. Invoke the orchestration with a task and the runtime
orchestration_result = await handoff_orchestration.invoke(
    task=user_input,
    runtime=runtime,
)

# 4. Wait for the results
value = await orchestration_result.get()
print(f"***** Result *****\n{value}")

await runtime.stop_when_idle()
# Out:
# PlannerAgent: Here is the complete database schema:
#
# **customers**
# - customer_id (integer, PRIMARY KEY, NOT NULL)
# - name (varchar, NOT NULL)
# - email (varchar, UNIQUE, NOT NULL)
# - city (varchar)
# - state (varchar)
# - country (varchar)
# - sentiment_score (numeric)
#
# **products**
# - product_id (integer, PRIMARY KEY, NOT NULL)
# - name (varchar, NOT NULL)
# - description (text)
# - price (numeric)
# - inventory (numeric)
# - refurbished (boolean)
# - category (varchar)
#
# **product_desc**
# - vector_id (integer, PRIMARY KEY, NOT NULL)
# - embedding (USER-DEFINED, NOT NULL)
# - product_id (integer, FOREIGN KEY to products.product_id)
#
# **product_desc_sk**
# - key (text, PRIMARY KEY, NOT NULL)
# - embedding (USER-DEFINED)
# - metadata (jsonb)
# - timestamp (timestamp)
#
# **sales**
# - sales_id (integer, PRIMARY KEY, NOT NULL)
# - customer_id (integer, FOREIGN KEY to customers.customer_id)
# - quantity (numeric)
# - product_id (integer, FOREIGN KEY to products.product_id)
# - sale_date (date)
#
# **shipments**
# - shipment_id (integer, PRIMARY KEY, NOT NULL)
# - sales_id (integer, FOREIGN KEY to sales.sales_id)
# - shipment_date (date)
# - shipment_status (varchar, NOT NULL)
# - latest_status_date (date)
#
# **return_items**
# - return_id (integer, PRIMARY KEY, NOT NULL)
# - sales_id (integer, FOREIGN KEY to sales.sales_id)
# - return_status (varchar, NOT NULL)
# - reason (text)
# - status_date (date)
#
# **reviews**
# - review_id (integer, PRIMARY KEY, NOT NULL)
# - customer_id (integer, FOREIGN KEY to customers.customer_id)
# - product_id (integer)
# - sales_id (integer, FOREIGN KEY to sales.sales_id)
# - rating (integer)
# - review_text (text)
# - review_date (date)
#
# What would you like to do with this database? (For example: query some data, add records, analyze trends, etc.)
# WriteAgent: There is no stored procedure specifically designed for deleting a customer and all their associated records, so a custom deletion will be constructed. Here’s a safe, integrity-preserving approach based on your schema:
#
# To delete the customer with ID 1 and all associated records, I will:
# 1. Remove related records in this order to avoid referential integrity issues:
#    - Delete from reviews where customer_id = 1
#    - Delete from return_items where sales_id matches any sale by customer_id = 1
#    - Delete from shipments where sales_id matches any sale by customer_id = 1
#    - Delete from sales where customer_id = 1
# 2. Finally, delete the customer with customer_id = 1
#
# Would you like to proceed with deleting customer 1 and all this related information? Please confirm before I execute these queries.
# ***** Result *****
# Task is completed with summary: Customer with ID 1 and all associated records in reviews, return_items, shipments, and sales were successfully deleted from the database, preserving referential integrity.

# %% [markdown]
# ## Release connection pool after you are done.

# %%
##### release connnection pool #####
connection_pool.closeall()
